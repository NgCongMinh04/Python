# %% [markdown]
# **- Project nhỏ (2)**

# %% [markdown]
# **Project 1** : Covid project

# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('D:/tài liệu')

# %%
df1 = pd.read_csv('file4.csv')

# %%
df1.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
df1.shape
# Out:
# (321, 6)

# %%
df1.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
df1.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
import seaborn as sns  
import matplotlib.pyplot as plt

# %%
sns.heatmap(df1.isnull())
plt.show() #  xem lỗi 1 cách tổng quan

# %%
df1.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
# df1.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(10)

# %%
#df1.groupby('Region')['Confirmed', 'Recovered'].sum()

# %%
df1[~df1['Confirmed']<10] # ~ để phủ định
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
df1 = df1[~df1['Confirmed']<10]
df1
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
df1.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
#df1.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(20)

# %%
df1.groupby('Region').Deaths.sum().sort_values(ascending = False).head(10)
# Out:
# Region
# US             60967
# Italy          27682
# UK             26166
# Spain          24275
# France         24121
# Belgium         7501
# Germany         6467
# Iran            5957
# Brazil          5513
# Netherlands     4727
# Name: Deaths, dtype: int64

# %%
df1[df1.Region == 'Brazil']
# Out:
#          Date State  Region  Confirmed  Deaths  Recovered
# 22  4/29/2020   NaN  Brazil      79685    5513      34132

# %% [markdown]
# **Project 2** : London Housing data

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv(r"D:/file5.csv")

# %%
data.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
data.info
# Out:
# <bound method DataFrame.info of             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# ...

# %%
data.count
# Out:
# <bound method DataFrame.count of             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# ...

# %%
data.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
data.date = pd.to_datetime(data.date)

# %%
data['year'] = data.date.dt.year

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
data.insert(1, 'month' , data.date.dt.month)
data.head()
# Out:
#         date  month            area  average_price       code  houses_sold  \
# 0 1995-01-01      1  city of london          91449  E09000001         17.0
# 1 1995-02-01      2  city of london          82203  E09000001          7.0
# 2 1995-03-01      3  city of london          79121  E09000001         14.0
# 3 1995-04-01      4  city of london          77101  E09000001          7.0
# 4 1995-05-01      5  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995

# %%
data.drop(['month', 'year'], axis=1 , inplace=True)

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
data[data.no_of_crimes==0]
# Out:
#           date            area  average_price       code  houses_sold  \
# 72  2001-01-01  city of london         284262  E09000001         24.0
# 73  2001-02-01  city of london         198137  E09000001         37.0
# 74  2001-03-01  city of london         189033  E09000001         44.0
# 75  2001-04-01  city of london         205494  E09000001         38.0
# 76  2001-05-01  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178 2009-11-01  city of london         397909  E09000001         11.0
# 179 2009-12-01  city of london         411955  E09000001         16.0
# 180 2010-01-01  city of london         464436  E09000001         20.0
# 181 2010-02-01  city of london         490525  E09000001          9.0
# 182 2010-03-01  city of london         498241  E09000001         15.0
#
#      no_of_crimes
# 72            0.0
# 73            0.0
# 74            0.0
# 75            0.0
# 76            0.0
# ...

# %%
len(data[data.no_of_crimes==0])
# Out:
# 104

# %%
data['year'] = data.date.dt.year

# %%
df1 = data[data.area== 'england']
df1.groupby('year').average_price.max()
# Out:
# year
# 1995     53901
# 1996     55755
# 1997     61564
# 1998     65743
# 1999     75071
# 2000     84191
# 2001     95992
# 2002    119982
# 2003    138985
# 2004    160330
# 2005    167244
# 2006    182031
# 2007    194764
# 2008    191750
# 2009    174136
# 2010    180807
# 2011    177335
# 2012    180129
# 2013    188544
# 2014    203639
# 2015    219582
# 2016    231922
# 2017    242628
# 2018    248620
# 2019    250410
# 2020    247355
# Name: average_price, dtype: int64

# %%
df1 =data[data.average_price <1000000].area.sort_values(ascending= True)

# %%
df1.head(5)
# Out:
# 601    barking and dagenham
# 396    barking and dagenham
# 397    barking and dagenham
# 398    barking and dagenham
# 399    barking and dagenham
# Name: area, dtype: object

# %%
data.groupby('area').no_of_crimes.max()
# Out:
# area
# barking and dagenham      2049.0
# barnet                    2893.0
# bexley                    1914.0
# brent                     2937.0
# bromley                   2637.0
# camden                    4558.0
# city of london              10.0
# croydon                   3263.0
# ealing                    3401.0
# east midlands                NaN
# east of england              NaN
# enfield                   2798.0
# england                      NaN
# greenwich                 2853.0
# hackney                   3466.0
# hammersmith and fulham    2645.0
# haringey                  3199.0
# harrow                    1763.0
# havering                  1956.0
# hillingdon                2819.0
# hounslow                  2817.0
# inner london                 NaN
# islington                 3384.0
# kensington and chelsea    2778.0
# kingston upon thames      1379.0
# lambeth                   4701.0
# lewisham                  2813.0
# london                       NaN
# ...

# %%
data.groupby('area').no_of_crimes.min().sort_values(ascending=True)
# Out:
# area
# city of london               0.0
# kingston upon thames       692.0
# richmond upon thames       700.0
# sutton                     787.0
# merton                     819.0
# bexley                     860.0
# harrow                     937.0
# havering                  1130.0
# barking and dagenham      1217.0
# hammersmith and fulham    1323.0
# kensington and chelsea    1347.0
# bromley                   1441.0
# hillingdon                1445.0
# redbridge                 1487.0
# greenwich                 1513.0
# hounslow                  1529.0
# haringey                  1536.0
# waltham forest            1575.0
# wandsworth                1582.0
# enfield                   1635.0
# tower hamlets             1646.0
# lewisham                  1675.0
# barnet                    1703.0
# brent                     1850.0
# hackney                   1870.0
# islington                 1871.0
# ealing                    1871.0
# croydon                   2031.0
# ...

# %% [markdown]
# **- Numpy Nâng Cao**

# %%
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set() # để thiết lập các tham số mặc định cho các lô trình được tạo ra bằng Seaborn

# %%
# Gaussian Distribution 
xs = np.arange(-4,4,0.01)

plt.figure(figsize = [10,2])

sigma =1.0
mu = 0.0

N = 1/np.sqrt(2*np.pi*sigma**2)
fx = N*np.exp(-(xs-mu)**2/(2*sigma**2))

plt.plot(xs,fx)
plt.xlabel('x',fontsize =20)
plt.ylabel('probability')
plt.show()

# %%
# Cấp số nhân phân phối gaus 
xs = np.arange(-10,10,0.01)
plt.figure(figsize = [10,6])

sigmas = [ 1.0,1.5,2.0,2.5,3.0,3.5,4.0]
mus = [0.0,1.0,1.5,2.0,2.5,3.0,3.5]

for s,m in zip(sigmas,mus):
    
    N = 1/np.sqrt(2*np.pi*s**2)
    fx = N*np.exp(-(xs-m)**2/(2*s**2))
    plt.plot(xs,fx, label = "mu="+str(m)+",sigma="+str(s))
    
plt.xlabel('x')
plt.ylabel('probability')
plt.show()

# %%
# phân tích từng cái trong đó : 
xs = np.arange(-10,10,0.01)
plt.figure(figsize = [14,16])

sigmas = [ 1.0,1.5,2.0,2.5,3.0,3.5,4.0]
mus = [0.0,1.0,1.5,2.0,2.5,3.0,3.5]

k = 1
for s,m in zip(sigmas,mus):
    plt.subplot(4,2,k)
    N = 1/np.sqrt(2*np.pi*s**2)
    fx = N*np.exp(-(xs-m)**2/(2*s**2))
    
    plt.plot(xs,fx, label = "mu="+str(m)+",sigma="+str(s))
    plt.xlabel('x',fontsize =20)
    plt.ylabel('prabability')
    plt.legend() # được sử dụng trong thư viện Matplotlib cho Python để thêm chú giải vào biểu đồ. 
    k = k+1
plt.show()

# %%
# thao tác với nhiều mảng các mảng : 
xs = np.arange(0,3.14,0.1)
np.sin(xs)
# Out:
# array([0.        , 0.09983342, 0.19866933, 0.29552021, 0.38941834,
#        0.47942554, 0.56464247, 0.64421769, 0.71735609, 0.78332691,
#        0.84147098, 0.89120736, 0.93203909, 0.96355819, 0.98544973,
#        0.99749499, 0.9995736 , 0.99166481, 0.97384763, 0.94630009,
#        0.90929743, 0.86320937, 0.8084964 , 0.74570521, 0.67546318,
#        0.59847214, 0.51550137, 0.42737988, 0.33498815, 0.23924933,
#        0.14112001, 0.04158066])

# %%
np.cos(xs)
# Out:
# array([ 1.        ,  0.99500417,  0.98006658,  0.95533649,  0.92106099,
#         0.87758256,  0.82533561,  0.76484219,  0.69670671,  0.62160997,
#         0.54030231,  0.45359612,  0.36235775,  0.26749883,  0.16996714,
#         0.0707372 , -0.02919952, -0.12884449, -0.22720209, -0.32328957,
#        -0.41614684, -0.5048461 , -0.58850112, -0.66627602, -0.73739372,
#        -0.80114362, -0.85688875, -0.90407214, -0.94222234, -0.97095817,
#        -0.9899925 , -0.99913515])

# %%
# 1. liệt kê nhiều mảng 
[np.cos(n*xs) for n in range(1,5)]
# Out:
# [array([ 1.        ,  0.99500417,  0.98006658,  0.95533649,  0.92106099,
#          0.87758256,  0.82533561,  0.76484219,  0.69670671,  0.62160997,
#          0.54030231,  0.45359612,  0.36235775,  0.26749883,  0.16996714,
#          0.0707372 , -0.02919952, -0.12884449, -0.22720209, -0.32328957,
#         -0.41614684, -0.5048461 , -0.58850112, -0.66627602, -0.73739372,
#         -0.80114362, -0.85688875, -0.90407214, -0.94222234, -0.97095817,
#         -0.9899925 , -0.99913515]),
#  array([ 1.        ,  0.98006658,  0.92106099,  0.82533561,  0.69670671,
#          0.54030231,  0.36235775,  0.16996714, -0.02919952, -0.22720209,
#         -0.41614684, -0.58850112, -0.73739372, -0.85688875, -0.94222234,
#         -0.9899925 , -0.99829478, -0.96679819, -0.89675842, -0.79096771,
#         -0.65364362, -0.49026082, -0.30733287, -0.11215253,  0.08749898,
#          0.28366219,  0.46851667,  0.63469288,  0.77556588,  0.88551952,
#          0.96017029,  0.9965421 ]),
# ...

# %%
sum([np.cos(n*xs) for n in range(1,5)])
# Out:
# array([ 4.        ,  3.85146823,  3.4231699 ,  2.76463983,  1.95092594,
#         1.07247523,  0.22309756, -0.51225912, -1.0681813 , -1.40642268,
#        -1.51948065, -1.42971764, -1.18429539, -0.84680556, -0.48695014,
#        -0.16988081,  0.0531896 ,  0.15173255,  0.11908368, -0.02828465,
#        -0.2551202 , -0.51453694, -0.75669441, -0.93754707, -1.02623127,
#        -1.00991764, -0.89540092, -0.70725333, -0.48294025, -0.26579566,
#        -0.09709851, -0.00862608])

# %%
# giao động đơn : Y = A*sin(wt + phi)
fs = 100
ts = np.arange(0,60,1/fs)
np.sin(ts)
# Out:
# array([ 0.        ,  0.00999983,  0.01999867, ..., -0.27610536,
#        -0.28570267, -0.29527141])

# %%
freq = 0.5
ts*(2*np.pi*freq) #nháp
# Out:
# array([0.00000000e+00, 3.14159265e-02, 6.28318531e-02, ...,
#        1.88401311e+02, 1.88432727e+02, 1.88464143e+02])

# %%
# thuc hanh : 
fs = 100
ts = np.arange(0,60,1/fs)
amp = 1.0
freq = 0.025

'''initialize figure'''
plt.figure(figsize = [20,4])

'''create oscillation:  Y = Asin(wt)| w = 2.pi.f'''
ys = amp*np.sin(ts*(2*np.pi*freq))

lb = "amp: " + str(amp) + ",freq:" + str(freq)   
plt.plot(ts,ys, label = lb)
    
plt.xlabel("Time in seconds") 
plt.ylabel("Displacement")
plt.legend()
plt.show()

# %%
# biên độ và tần số giao động : 
fs = 100
ts = np.arange(0,60,1/fs)
'''initialize figure'''
plt.figure(figsize = [20,6])

'''iterate over each amplitude and 
frequency and create a oscillation plot'''

for i in range(1,10):
    amp = 100*1/float(i)
    freq = 0.025*i
    
    '''Y= A sin(wt) | w = 2*pi*f'''
    ys = amp*np.sin(ts*2*np.pi*freq)
    
    lb= "amp: "+str(amp)[0:4] + ",freq:"+str(freq)[0:4]
    plt.plot(ts,ys,label=lb )
    
plt.xlabel("Time in seconds") 
plt.ylabel("Displacement")
plt.legend()
plt.show()

# %%
# statistic :

# %%
import pandas as pd

# %%
A = np.random.rand(10,10)
np.cov(A) # hiệp phương sai
# Out:
# array([[ 0.05113563,  0.0031948 , -0.01515129,  0.01740416, -0.00361432,
#          0.0003788 , -0.00194098, -0.0170308 ,  0.00416824,  0.00342591],
#        [ 0.0031948 ,  0.07794513, -0.01087028,  0.00203334, -0.01269543,
#          0.01997288, -0.03165155,  0.03675983,  0.04403876,  0.02719558],
#        [-0.01515129, -0.01087028,  0.07815924, -0.0313463 , -0.01023087,
#          0.02478554, -0.01320257,  0.02468661, -0.01801566, -0.01592413],
#        [ 0.01740416,  0.00203334, -0.0313463 ,  0.07198984,  0.023765  ,
#          0.01662234, -0.01045494, -0.03843059,  0.0231152 ,  0.00996849],
#        [-0.00361432, -0.01269543, -0.01023087,  0.023765  ,  0.06962239,
#          0.01512932, -0.04742298, -0.03709298,  0.03358837, -0.0155571 ],
#        [ 0.0003788 ,  0.01997288,  0.02478554,  0.01662234,  0.01512932,
#          0.04585988, -0.03371163,  0.00077342,  0.02682428,  0.01353721],
#        [-0.00194098, -0.03165155, -0.01320257, -0.01045494, -0.04742298,
# ...

# %%
np.mean(A,axis =0) # tính row
# Out:
# array([0.44391439, 0.44562504, 0.31133204, 0.43670545, 0.49345399,
#        0.40727456, 0.39425823, 0.62793262, 0.48487052, 0.57532182])

# %% [markdown]
# Bayesian Classifier : Example of Machine Learning in Bayesian theory
#
# Boltzman Machine: Example of Machine Learning for Physicist.
#
# Quantum Boltzman Machine: Fusion of Machine Learning and Quantum Physics
#
# Markove Random Field: Is there a Field Theory in Machine Learning?

# %%
# bayes 
A = (100*np.random.rand(10,4)).astype(int)
A
# Out:
# array([[75, 36, 68, 36],
#        [97, 41, 75, 88],
#        [25, 58, 95,  0],
#        [ 2, 93, 90, 80],
#        [92, 72, 20, 32],
#        [32, 57, 35, 23],
#        [97, 23, 62,  3],
#        [75, 17, 85, 35],
#        [50, 92, 67, 78],
#        [65, 45, 36,  9]])

# %%
df = pd.DataFrame(A, columns= ['bud','green','ripen','rotten'],\
                  index= ['apple','guava','mango','orange','banana','pear','papaya','strwberrey','grape','melon'])

# %%
df
# Out:
#             bud  green  ripen  rotten
# apple        75     36     68      36
# guava        97     41     75      88
# mango        25     58     95       0
# orange        2     93     90      80
# banana       92     72     20      32
# pear         32     57     35      23
# papaya       97     23     62       3
# strwberrey   75     17     85      35
# grape        50     92     67      78
# melon        65     45     36       9

# %%
df.loc['apple','bud']
# Out:
# np.int64(75)

# %%
# xác xuất apple trên riven : 
p_apple = df.loc['apple',:].sum()/sum(df.sum())
p_ripen_given_apple = df.loc['apple','ripen']/df.loc['apple',:].sum()
p_ripen = df.loc[:,'ripen'].sum()/sum(df.sum())

p_apple_given_ripen = (p_ripen_given_apple*p_apple)/p_ripen
p_apple_given_ripen
# Out:
# np.float64(0.10742496050552924)

# %% [markdown]
# **Xác xuất** : https://nbviewer.org/github/npshub/numpy/blob/master/5a.%20Statistics-Probability.ipynb
#
# **Lấy mẫu** : https://nbviewer.org/github/npshub/numpy/blob/master/5b.%20Statistics-Smpling.ipynb
#
# **Tài liệu đọc thêm** : https://www.w3schools.com/python/numpy/numpy_random_normal.asp

# %% [markdown]
# **- Pandas Nâng cao**

# %% [markdown]
# **Tài Liệu đọc thêm MySQL** : https://www.w3schools.com/python/python_mysql_getstarted.asp .
#
# **Tài Liệu đọc thêm MonggoDB** : https://www.w3schools.com/python/python_mongodb_getstarted.asp

# %%
# pandas plot :

# %% [markdown]
# **Biểu đồ màu** : https://matplotlib.org/2.0.2/users/colormaps.html

# %%
df5 = pd.read_csv(r"D:/Ice Cream Ratings.csv")

# %%
df5.head(5)
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264
# 2  1/3/2022       0.442323        0.044154        0.598112
# 3  1/4/2022       0.389128        0.549676        0.489353
# 4  1/5/2022       0.386887        0.519439        0.988280

# %%
df5.set_index('Date')
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
# chọn plt 
print(plt.style.available)
plt.style.use('dark_background')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# **- Biểu đồ Line**

# %%
#df5.plot()
#df5.plot(kind= 'line') #tạo biểu đồ đường thẳng. 
#df5.plot(kind= 'line', subplots= True) # chia mỗi data thành từng biểu đồ 
df5.plot(kind= 'line',title='Bảng thông tin kem',xlabel='Daily Rating',ylabel='năm') # tên biểu đồ
# Out:
# <Axes: title={'center': 'Bảng thông tin kem'}, xlabel='Daily Rating', ylabel='năm'>

# %% [markdown]
# **- Biểu đồ Bar**

# %%
#df5.plot(kind='bar',stacked=True) # áp dụng full dữ liệu .
df5['Flavor Rating'].plot(kind='bar',stacked=True) # áp dụng 1 loại dữ liệu
# Out:
# <Axes: >

# %%
df5.head(2)
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264

# %%
df5.plot.barh(stacked = True)
# Out:
# <Axes: >

# %% [markdown]
# **- Biểu đồ Scatter**

# %%
df5.plot.scatter(x='Texture Rating', y = 'Overall Rating',s= 500 , c= 'Red')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %% [markdown]
# **- Biểu đồ Histogram**

# %%
#df5.plot.hist(bins = 20) # chỉnh kích thước 
df5.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **- Biểu đồ Boxplot**

# %%
df5.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# **- Biểu đồ Area**

# %%
df5.plot.area(figsize =(10,5))
# Out:
# <Axes: >

# %% [markdown]
# **- Biểu đồ Pie**

# %%
df5.plot.pie(y='Flavor Rating',figsize=(10,6))
# Out:
# <Axes: ylabel='Flavor Rating'>
